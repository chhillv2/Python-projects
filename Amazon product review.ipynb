# %% [raw]
# reset -fs

# %%
import gzip
import itertools
import string
import wordcloud
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import pylab as pl

from collections import Counter
from sklearn import svm
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score

from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

# %matplotlib inline

# %%
wordcloud
# Out:
# <module 'wordcloud' from '/anaconda2/lib/python2.7/site-packages/wordcloud/__init__.pyc'>

# %%
def parse_gz(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

def convert_to_DF(path):
    i = 0
    df = {}
    for d in parse_gz(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

# %%
sports_outdoors = convert_to_DF('/Users/vikaschhillar/Downloads/reviews_Sports_and_Outdoors_5.json.gz')

# %%
print('Dataset size: {:,} words'.format(len(sports_outdoors)))
# Out:
# Dataset size: 296,337 words

# %%
sports_outdoors["reviewTime"] = pd.to_datetime(sports_outdoors["reviewTime"])

# %%
sports_outdoors = sports_outdoors[['asin', 'summary', 'reviewText', 'overall', 'reviewerID', 'reviewerName', 'helpful', 'reviewTime',
      'unixReviewTime']]

# %%
sports_outdoors.head(100)
# Out:
#           asin                                            summary  \
# 0   1881509818                                     Woks very good
# 1   1881509818                  Works as well as the factory tool
# 2   1881509818                          It's a punch, that's all.
# 3   1881509818                    It's a punch with a Glock logo.
# 4   1881509818            Ok,tool does what a regular punch does.
# 5   1881509818  Glock punch tool - needed for your Glock and o...
# 6   1881509818                                         Great tool
# 7   2094869245                                            Bright!
# 8   2094869245                                            Be seen
# 9   2094869245                            Bicycle rear tail light
# 10  2094869245                                         Great lite
# 11  2094869245                  It's worth the price they charge.
# 12  2094869245                            For $11, it's a bargain
# 13  2094869245                                              Bulky
# 14  2094869245                                           Love it!
# 15  2094869245                                      Bulky but....
# 16  2094869245                                    rear bike light
# 17  2094869245                       Needed a little modification
# 18  2094869245  Good light for the price, Laser iight is just ...
# 19  7245456259             resistance was good but quality wasn't
# 20  7245456259                             Girlfriend loves these
# 21  7245456259                I'm not opposed to this resistance!
# 22  7245456259                            I BOUGHT THE PURPLE ONE
# 23  7245456259                               good resistance band
# 24  7245456259                                      Great device.
# 25  7245456259               Great product, even greater company.
# 26  7245456313                                  Excellent product
# 27  7245456313                                       Gym in a bag
# 28  7245456313                                         Great set.
# 29  7245456313                                            Love it
# ..         ...                                                ...
# 70  7245456313               BLACK MOUNTAIN PRODUCTS UPS ITS GAME
# 71  7245456313                                   I like the bands
# 72  7245456313                                        Work Great!
# 73  7245456313                           Love Love Love the bands
# 74  7245456313                           Good product, fair price
# 75  7245456313                            Defective - Be Careful!
# 76  7245456313                                           Worth It
# 77  7245456313                        GREAT product for the money
# 78  7245456313                                       really great
# 79  7245456313                       Nice set of resistance bands
# 80  7245456313                                          Nice Set!
# 81  7245456313                                 Work well for P90X
# 82  7245456313                                     black mountain
# 83  7245456313                                    Who needs gyms?
# 84  7245456313                                     Great for P90X
# 85  7245456313                                        Lightweight
# 86  7245456313                                         Good bands
# 87  7245456313      Resistance Band Set - Black Mountain Products
# 88  7245456313                       Nice Set of Resistance Bands
# 89  7245456313                                     Great bands!!!
# 90  7245456313  Works great for my needs, but they are minimal...
# 91  7245456313  Awesome kit, would've paid more for a single b...
# 92  7245456313                                 Good for the Money
# 93  7245456313                                      As Advertised
# 94  7245456313  Great product, awesome warranty, amazing custo...
# 95  7245456313                                      Wore out fast
# 96  7245456313                                   resistance bands
# 97  7245456313                                      bought 2 sets
# 98  7245456313                                   Good starter set
# 99  7245456313                                      Great Product
#
#                                            reviewText  overall  \
# 0   This came in on time and I am veru happy with ...      5.0
# 1   I had a factory Glock tool that I was using fo...      5.0
# 2   If you don't have a 3/32 punch or would like t...      4.0
# 3   This works no better than any 3/32 punch you w...      4.0
# 4   I purchased this thinking maybe I need a speci...      4.0
# 5   Needed this tool to really break down my G22, ...      5.0
# 6   If u don't have it .. Get it. All you need to ...      5.0
# 7   This light will no doubt capture the attention...      4.0
# 8   Light and laser torch work well, very bright. ...      5.0
# 9   Does everything it says it will do. I would li...      5.0
# 10  Very bright.  I would recommend this lite to a...      4.0
# 11  It's cheaply made but does what it is supposed...      3.0
# 12  Mine arrived with only one of the lane-generat...      5.0
# 13  It works great its just a little bulky... I fe...      4.0
# 14  I love this light! I have two of these! It is ...      5.0
# 15  Bit bulky. One button is sticky. Works for now...      5.0
# 16  it is bright and it has multiple settings for ...      5.0
# 17  A mice bright light with multiple modes. I wou...      4.0
# 18  Had one ride on the light! Mounted on my cross...      4.0
# 19  So it worked well for a couple weeks, but duri...      2.0
# 20  My girlfriend is disabled and cant do high imp...      5.0
# 21  I worked out once back in '08. I picked up som...      5.0
# 22  I bought the purple one to add to my Strong Ma...      5.0
# 23  Well I have had this band for about a month an...      5.0
# 24  Works just as advertised. Great, soft, but rug...      5.0
# 25  This band works well, and has lasted a long ti...      5.0
# 26  These bands were as claimed all sizex and good...      5.0
# 27  If you are creative, you can do almost any exe...      5.0
# 28  I like it but I have to say I wish they includ...      4.0
# 29  Love the wide variety of resistances you can c...      5.0
# ..                                                ...      ...
# 70  When I bought the previous version that had th...      4.0
# 71  Not a whole lot to say about them, other than ...      4.0
# 72  My wife and I both use these, and they are gre...      5.0
# 73  My arms are burning as I try to type this revi...      5.0
# 74  I'm using this to work out my hips for an IT B...      4.0
# 75  I wish I would have taken the warnings I read ...      1.0
# 76  For the price and what you get i love it, band...      5.0
# 77  I used to be a personal trainer and I needed s...      5.0
# 78  i purchased these to help with a shoulder inju...      5.0
# 79  I bought these resistance bands to use along w...      4.0
# 80  This resistance band set is great. In fact, I ...      5.0
# 81  I am about half way through the P90X workout a...      4.0
# 82  I am able to replicate all of the exercises th...      4.0
# 83  I was a little skeptical at first wondering ho...      5.0
# 84  Bought these to supplement the other Black Mou...      4.0
# 85  I travel with these and it don't add a lot wei...      5.0
# 86  These bands are some of the most well construc...      5.0
# 87  This is a nice assortment of workout bands--th...      5.0
# 88  I purchased the Black Mountain Resistance Band...      4.0
# 89  I primarily use these attached to the door, I ...      5.0
# 90  I have bad knees. They often hurt a LOT and I ...      5.0
# 91  I currently use these bands for my P90x!Pros:Y...      5.0
# 92  I like the bands.  The quality of the bands an...      4.0
# 93  I purchased the Black Mountain Resistance Band...      5.0
# 94  I bought this band set just over 2 years ago a...      5.0
# 95  I bought these to use when I tried P90X, and t...      3.0
# 96  The reason I went with these was to be able to...      4.0
# 97  I bought one set for my wife and my mother in ...      5.0
# 98  Everything a beginner to resistance bands need...      5.0
# 99  I looked around and compared item and price an...      5.0
#
#         reviewerID                    reviewerName helpful reviewTime  \
# 0     AIXZKN4ACSKI                    David Briner  [0, 0] 2014-01-26
# 1   A1L5P841VIO02V                 Jason A. Kramer  [1, 1] 2012-02-02
# 2    AB2W04NI4OEAD                      J. Fernald  [2, 2] 2012-02-28
# 3   A148SVSWKTJKU6  Jusitn A. Watts "Maverick9614"  [0, 0] 2012-02-05
# 4    AAAWJ6LW9WMOO                    Material Man  [0, 0] 2013-04-23
# 5   A2XX2A4OJCDNLZ             RatherLiveInKeyWest  [0, 0] 2012-11-02
# 6   A283UOBQRUNM4Q                   Thomas Dragon  [0, 0] 2014-06-10
# 7    AWG3H90WVZ0Z1                     Alec Nelson  [0, 0] 2013-08-31
# 8   A3V52OTJHKIJZX   A. Saenz Jr. "Bettering self"  [0, 1] 2013-05-27
# 9   A3SZBE5F3UQ9EC               ChasRat "ChasRat"  [0, 0] 2013-11-02
# 10  A2HVMUMOKOGCQ9                        G. Inman  [0, 0] 2014-05-07
# 11  A21AJ9GNCM89MK                            Greg  [0, 0] 2014-01-07
# 12  A10X9ME6R66JDX               Hugo M. M. Rabson  [0, 0] 2014-01-14
# 13  A2I7K5OIEXUI6R       Lswieckitay "Lswieckitay"  [0, 0] 2013-12-20
# 14  A2RCMHV3MHEBDP                      Micah Chan  [0, 0] 2013-09-18
# 15  A2A26KED39175E                    Pudknocker71  [0, 0] 2014-01-16
# 16   ANKZUDSZFUMNZ                          ronald  [0, 0] 2013-12-07
# 17  A2M93OC5AOMMM3                         Vette71  [0, 0] 2013-11-04
# 18   AO3M0AXLL0AGW                    Vic D "Cope"  [0, 0] 2013-11-12
# 19  A2NFEGCOY2TO1Q                            Adam  [0, 0] 2014-03-28
# 20  A16VC5E75E3KT4                          Dan B.  [0, 0] 2013-09-05
# 21   ACH40GDEWZRJS                     Dark Harden  [0, 0] 2014-07-06
# 22   AHRQOLXJE4CBV              JACK LOBO "ljb926"  [0, 1] 2013-07-13
# 23  A3AFVG8GJRVFM1           Melchor Orozco-Marron  [0, 2] 2013-06-27
# 24  A27M3YPDI1YU5B                        R. Davis  [0, 0] 2014-04-17
# 25  A1YYDO3HZHED58            Ryan Nathaniel White  [0, 0] 2013-03-09
# 26  A1CJ6O4N4ZWGGR   Afrikan "Freedom is not free"  [0, 0] 2014-01-24
# 27  A29NO61G1WH74V                    Alan Smithee  [0, 0] 2013-04-12
# 28  A2ZWD1RON75HX3                              Al  [0, 0] 2014-07-06
# 29  A1XLWJPVB4WEMP                 Amazon Customer  [0, 0] 2012-12-15
# ..             ...                             ...     ...        ...
# 70   AHRQOLXJE4CBV              JACK LOBO "ljb926"  [0, 0] 2012-07-31
# 71   A76LAIUAWMDC7                       jalmquist  [0, 0] 2013-07-16
# 72  A121QRWXZIO6UP               Jarrett Venturini  [0, 0] 2013-04-24
# 73  A12G8WFVFU2RGO                     J. Dubberly  [2, 2] 2013-01-24
# 74  A2FUNN2NPIZXIA                         J. Horn  [0, 0] 2013-05-22
# 75   A2XWNL7JV2VE7                            J.L.  [6, 8] 2012-12-03
# 76  A163KRCXD2S2BV                             Joe  [0, 0] 2013-10-03
# 77  A2ZSSWYJQ8MO73                John L. Robb Jr.  [0, 1] 2011-05-09
# 78  A3RWLSUWYHZBU0                     Jonathan O.  [0, 0] 2013-05-09
# 79  A3MALXREVOLP3H                       J. Valcik  [0, 0] 2012-05-23
# 80  A2KQC4QQ8BPOLA                           Kevin  [0, 0] 2014-04-02
# 81  A2ZHSHIVYKUFQQ                              KG  [0, 0] 2013-12-17
# 82   A2ZJ2KR4ADH0E                 Kindle Customer  [1, 1] 2013-11-29
# 83  A3TMS7JNHRLAHY                       K. Temple  [1, 1] 2014-05-29
# 84  A32U0TAQSEYKSD                         Laxoman  [0, 0] 2014-04-08
# 85  A1M4DGN0YSNWDU                             lay  [1, 1] 2013-07-10
# 86  A14OG85Y77RQVY       L. Dumas "Shopping in NY"  [0, 0] 2012-06-21
# 87   AKCDHGUSKVJ72             LeelaFry "Leelafry"  [0, 0] 2013-11-10
# 88  A3GM1FLRD7BEOE                   lewisandclark  [0, 0] 2013-01-16
# 89  A2CGOA2CIARNDF                            Lisa  [0, 0] 2014-02-07
# 90  A25JUE9AFX7SUC                         Matthew  [0, 0] 2014-07-09
# 91  A1JG26BY6RTI51                            Mike  [0, 0] 2013-02-09
# 92  A1L664MXWAK3MJ                       Mike Honn  [0, 0] 2014-01-23
# 93  A2YKP1BTRUV92U                 Miles T. Hanley  [0, 1] 2012-01-10
# 94   AH530FH6MJ2TL                            Mmmk  [0, 0] 2014-05-15
# 95  A14DI9HDK2JTEC                         N. Daly  [0, 0] 2014-02-17
# 96  A16C3WD781AA2M                        Newton S  [0, 0] 2014-07-02
# 97   ATWO5DIP5Z9YE                          Nick M  [0, 1] 2013-07-03
# 98  A23XF8U25MSZD6                      nick rumke  [0, 0] 2013-11-01
# 99  A13S8UK2JVP52O                  PATRICK SNYDER  [0, 0] 2014-01-13
#
#     unixReviewTime
# 0       1390694400
# 1       1328140800
# 2       1330387200
# 3       1328400000
# 4       1366675200
# 5       1351814400
# 6       1402358400
# 7       1377907200
# 8       1369612800
# 9       1383350400
# 10      1399420800
# 11      1389052800
# 12      1389657600
# 13      1387497600
# 14      1379462400
# 15      1389830400
# 16      1386374400
# 17      1383523200
# 18      1384214400
# 19      1395964800
# 20      1378339200
# 21      1404604800
# 22      1373673600
# 23      1372291200
# 24      1397692800
# 25      1362787200
# 26      1390521600
# 27      1365724800
# 28      1404604800
# 29      1355529600
# ..             ...
# 70      1343692800
# 71      1373932800
# 72      1366761600
# 73      1358985600
# 74      1369180800
# 75      1354492800
# 76      1380758400
# 77      1304899200
# 78      1368057600
# 79      1337731200
# 80      1396396800
# 81      1387238400
# 82      1385683200
# 83      1401321600
# 84      1396915200
# 85      1373414400
# 86      1340236800
# 87      1384041600
# 88      1358294400
# 89      1391731200
# 90      1404864000
# 91      1360368000
# 92      1390435200
# 93      1326153600
# 94      1400112000
# 95      1392595200
# 96      1404259200
# 97      1372809600
# 98      1383264000
# 99      1389571200
#
# [100 rows x 9 columns]

# %%
products = sports_outdoors['overall'].groupby(sports_outdoors['asin']).count()
print("Number of Unique Products in the Sports & Outdoors Category = {}".format(products.count()))
# Out:
# Number of Unique Products in the Sports & Outdoors Category = 18357

# %%
sorted_products = products.sort_values(ascending=False)

print("Top 20 Reviewed Products:\n")
print(sorted_products[:20], )
print('Most Reviewed Product, B001HBHNHE - has {} reviews.'.format(products.max()))
# Out:
# Top 20 Reviewed Products:
#
# (asin
# B001HBHNHE    1042
# B001T7QJ9O     763
# B000S5ODN2     647
# B0010O748Q     513
# B0000C50K3     427
# B002ZYRV2E     401
# B002OKWHVO     398
# B000GCRWCG     393
# B001HBHNHY     372
# B0035L35A8     359
# B004U8CP88     357
# B001WJ577O     355
# B004TNWD40     349
# B006X9DLQM     344
# B00178CS4K     343
# B006QF3TW4     323
# B003NFI092     309
# B00200E0HM     307
# B001949TKS     298
# B000JZ7JM8     293
# Name: overall, dtype: int64,)
# Most Reviewed Product, B001HBHNHE - has 1042 reviews.

# %%
def tokenize(text):
    tokenized = word_tokenize(text)
    no_punc = []
    for review in tokenized:
        line = "".join(char for char in review if char not in string.punctuation)
        no_punc.append(line)
    tokens = lemmatize(no_punc)
    return tokens


def lemmatize(tokens):
    lmtzr = WordNetLemmatizer()
    lemma = [lmtzr.lemmatize(t) for t in tokens]
    return lemma

# %%
reviews = sports_outdoors['reviewText']

# %%
reviews = reviews.apply(lambda x: tokenize(x))

# %%
reviews[:11]
# Out:
# 0     [This, came, in, on, time, and, I, am, veru, h...
# 1     [I, had, a, factory, Glock, tool, that, I, wa,...
# 2     [If, you, do, nt, have, a, 332, punch, or, wou...
# 3     [This, work, no, better, than, any, 332, punch...
# 4     [I, purchased, this, thinking, maybe, I, need,...
# 5     [Needed, this, tool, to, really, break, down, ...
# 6     [If, u, do, nt, have, it, , Get, it, , All, yo...
# 7     [This, light, will, no, doubt, capture, the, a...
# 8     [Light, and, laser, torch, work, well, , very,...
# 9     [Does, everything, it, say, it, will, do, , I,...
# 10    [Very, bright, , I, would, recommend, this, li...
# Name: reviewText, dtype: object

# %%
cloud = wordcloud.WordCloud(background_color='gray', max_font_size=60, 
                                relative_scaling=1).generate(' '.join(sports_outdoors.reviewText))

# %%
sorted_products[9178:9180]

# %%
print("Bottom 20 Reviewed Products:\n")
print(sorted_products[18337:])
print('Least Reviewed Product (Sorted), B003Z6HUZE - has {} reviews.'.format(products.min()))

# %%
products.mode()

# %%
sports_outdoors['reviewText'][:11]

# %%
stops = stopwords.words('english')

# %%
stops
