# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
% matplotlib inline
import seaborn as sns
from subprocess import check_output

# %%
print(check_output(["ls", "../input"]).decode("utf8"))
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-4-7a23cd48126a> in <module>()
# ----> 1 print(check_output(["ls", "../input"]).decode("utf8"))
#
# /Users/vikaschhillar/anaconda/lib/python3.6/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     334
#     335     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 336                **kwargs).stdout
#     337
#     338
#
# /Users/vikaschhillar/anaconda/lib/python3.6/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     416         if check and retcode:
#     417             raise CalledProcessError(retcode, process.args,
# --> 418                                      output=stdout, stderr=stderr)
#     419     return CompletedProcess(process.args, retcode, stdout, stderr)
#     420
#
# ...

# %%
prep_cars=pd.read_csv('/Users/vikaschhillar/Downloads/used-cars-database/autos.csv', encoding='latin_1')
columns_to_keep = ['brand','model','vehicleType','yearOfRegistration',
                   'monthOfRegistration','kilometer','powerPS','fuelType',
                   'gearbox','abtest','notRepairedDamage','price']
prep_cars = prep_cars[columns_to_keep]
print(len(prep_cars))
# Out:
# 371528

# %%
prep_cars = prep_cars[x]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d99b12841240> in <module>()
# ----> 1 prep_cars = prep_cars[x]
#
# NameError: name 'x' is not defined

# %%
prep_cars.head()
# Out:
#         brand  model vehicleType  yearOfRegistration  monthOfRegistration  \
# 0  volkswagen   golf         NaN                1993                    0
# 1        audi    NaN       coupe                2011                    5
# 2        jeep  grand         suv                2004                    8
# 3  volkswagen   golf  kleinwagen                2001                    6
# 4       skoda  fabia  kleinwagen                2008                    7
#
#    kilometer  powerPS fuelType    gearbox abtest notRepairedDamage  price
# 0     150000        0   benzin    manuell   test               NaN    480
# 1     125000      190   diesel    manuell   test                ja  18300
# 2     125000      163   diesel  automatik   test               NaN   9800
# 3     150000       75   benzin    manuell   test              nein   1500
# 4      90000       69   diesel    manuell   test              nein   3600

# %%
for col in prep_cars.columns:
    if col[:]=='vehicleType':
        prep_cars.rename(columns={col:'car_type'}, inplace=True)
    if col[:]=='yearOfRegistration': 
        prep_cars.rename(columns={col:'reg_year'}, inplace=True)
    if col[:]=='monthOfRegistration': 
        prep_cars.rename(columns={col:'reg_month'}, inplace=True)
    if col[:]=='notRepairedDamage':
        prep_cars.rename(columns={col:'damage'}, inplace=True)   
prep_cars['damage'].fillna('norep', inplace=True)
prep_cars = prep_cars.dropna()
prep_cars.head()
# Out:
#         brand    model    car_type  reg_year  reg_month  kilometer  powerPS  \
# 2        jeep    grand         suv      2004          8     125000      163
# 3  volkswagen     golf  kleinwagen      2001          6     150000       75
# 4       skoda    fabia  kleinwagen      2008          7      90000       69
# 5         bmw      3er   limousine      1995         10     150000      102
# 6     peugeot  2_reihe      cabrio      2004          8     150000      109
#
#   fuelType    gearbox abtest damage  price
# 2   diesel  automatik   test  norep   9800
# 3   benzin    manuell   test   nein   1500
# 4   diesel    manuell   test   nein   3600
# 5   benzin    manuell   test     ja    650
# 6   benzin    manuell   test   nein   2200

# %%
print('Number of listed cars is: ', len(prep_cars))
# Out:
# Number of listed cars is:  299864

# %%
len(prep_cars)
# Out:
# 299864

# %%
def age_count(yr, mt):                    # counting the age of the car as the time from
    return (2015-yr)*12+(12-mt)+3        # registration to April,1,2016
                                        # introducing a new attribute = car age in months  
prep_cars['age_months'] = age_count(prep_cars['reg_year'],prep_cars['reg_month'])

# %%
prep_cars['km/1000'] = prep_cars['kilometer']/1000       # scaled feature in a new column
prep_cars.head(2)
# Out:
#         brand  model    car_type  reg_year  reg_month  kilometer  powerPS  \
# 2        jeep  grand         suv      2004          8     125000      163
# 3  volkswagen   golf  kleinwagen      2001          6     150000       75
#
#   fuelType    gearbox abtest damage  price  age_months  km/1000
# 2   diesel  automatik   test  norep   9800         139    125.0
# 3   benzin    manuell   test   nein   1500         177    150.0

# %%
prep_cars['km/1000'] = prep_cars['kilometer']/1000       # scaled feature in a new column
prep_cars.head(2)
# Out:
#         brand  model    car_type  reg_year  reg_month  kilometer  powerPS  \
# 2        jeep  grand         suv      2004          8     125000      163
# 3  volkswagen   golf  kleinwagen      2001          6     150000       75
#
#   fuelType    gearbox abtest damage  price  age_months  km/1000
# 2   diesel  automatik   test  norep   9800         139    125.0
# 3   benzin    manuell   test   nein   1500         177    150.0

# %%
prep_cars=prep_cars['kilometer/1000']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/vikaschhillar/anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'kilometer/1000'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
prep_cars['kilometer']/1000
# Out:
# 2         125.0
# 3         150.0
# 4          90.0
# 5         150.0
# 6         150.0
# 7          40.0
# 8          30.0
# 10        150.0
# 11        150.0
# 12        150.0
# 14         70.0
# 17        150.0
# 18        150.0
# 19        150.0
# 20        100.0
# 21        150.0
# 23        150.0
# 24        150.0
# 25        150.0
# 27         60.0
# 28          5.0
# 29        150.0
# 30        150.0
# 33         20.0
# 34        150.0
# 38        150.0
# 39        150.0
# 42        150.0
# 43        100.0
# 44         80.0
#           ...
# 371490    125.0
# 371491    150.0
# 371492    100.0
# 371494    125.0
# 371497    150.0
# 371498    150.0
# 371499    150.0
# 371500     30.0
# 371501    150.0
# 371502    150.0
# 371503     70.0
# 371505    150.0
# 371506    150.0
# 371507    150.0
# 371508    150.0
# 371510    150.0
# 371511    150.0
# 371512    150.0
# 371513    150.0
# 371514    150.0
# 371515    150.0
# 371516    150.0
# 371517    150.0
# 371518    150.0
# ...

# %%
prep_cars['km/1000']/1000
# Out:
# 2         0.125
# 3         0.150
# 4         0.090
# 5         0.150
# 6         0.150
# 7         0.040
# 8         0.030
# 10        0.150
# 11        0.150
# 12        0.150
# 14        0.070
# 17        0.150
# 18        0.150
# 19        0.150
# 20        0.100
# 21        0.150
# 23        0.150
# 24        0.150
# 25        0.150
# 27        0.060
# 28        0.005
# 29        0.150
# 30        0.150
# 33        0.020
# 34        0.150
# 38        0.150
# 39        0.150
# 42        0.150
# 43        0.100
# 44        0.080
#           ...
# 371490    0.125
# 371491    0.150
# 371492    0.100
# 371494    0.125
# 371497    0.150
# 371498    0.150
# 371499    0.150
# 371500    0.030
# 371501    0.150
# 371502    0.150
# 371503    0.070
# 371505    0.150
# 371506    0.150
# 371507    0.150
# 371508    0.150
# 371510    0.150
# 371511    0.150
# 371512    0.150
# 371513    0.150
# 371514    0.150
# 371515    0.150
# 371516    0.150
# 371517    0.150
# 371518    0.150
# ...

# %%
x= ['brand','model','car_type','reg_year','age_months','km/1000',
                   'powerPS','fuelType','gearbox','abtest','damage','price']
prep_cars = prep_cars[x]
sel_cars = prep_cars[(prep_cars.age_months >= 0)&(prep_cars.price <= 150000)&
                     (prep_cars.price > 100)]
sel_cars.head(3)                   # removing records with invalid or very extreme values

# %%
prep_cars1=pd.read_csv('/Users/vikaschhillar/Downloads/Untitled23.ipynb', encoding='latin_1')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-3-82c4271809d9> in <module>()
# ----> 1 prep_cars1=pd.read_csv('/Users/vikaschhillar/Downloads/Untitled23.ipynb', encoding='latin_1')
#
# ...

# %%
prep_cars
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0e943bd6282a> in <module>()
# ----> 1 prep_cars
#
# NameError: name 'prep_cars' is not defined

# %%
prep_cars
# Out:
#                  brand        model vehicleType  yearOfRegistration  \
# 0           volkswagen         golf         NaN                1993
# 1                 audi          NaN       coupe                2011
# 2                 jeep        grand         suv                2004
# 3           volkswagen         golf  kleinwagen                2001
# 4                skoda        fabia  kleinwagen                2008
# 5                  bmw          3er   limousine                1995
# 6              peugeot      2_reihe      cabrio                2004
# 7           volkswagen       andere   limousine                1980
# 8                 ford        c_max         bus                2014
# 9           volkswagen         golf  kleinwagen                1998
# 10               mazda      3_reihe   limousine                2004
# 11          volkswagen       passat       kombi                2005
# 12          volkswagen       passat       kombi                1995
# ...

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score, mean_absolute_error

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib notebook
# %matplotlib inline

# %%
x= '/Users/vikaschhillar/Downloads/used-cars-database (2)/autos.csv'
second_cars= pd.read_csv(x, encoding='Latin1')

# %%
head(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-90d98bc75081> in <module>()
# ----> 1 head(x)
#
# NameError: name 'head' is not defined

# %%
pd.to_numeric(second_cars.yearOfRegistration, errors='raise')
second_cars= second_cars[second_cars.yearOfRegistration > 2004]
second_cars = second_cars[second_cars.yearOfRegistration <= 2016]

# %%
second_cars =second_cars[second_cars.price> 150]
second_cars = second_cars[second_cars.price < 45000]
second_cars.head()
# Out:
#             dateCrawled                                               name  \
# 1   2016-03-24 10:58:45                               A5_Sportback_2.7_Tdi
# 4   2016-03-31 17:25:20                     Skoda_Fabia_1.4_TDI_PD_Classic
# 8   2016-04-04 23:42:13               Ford_C___Max_Titanium_1_0_L_EcoBoost
# 11  2016-04-07 10:06:22      Volkswagen_Passat_Variant_2.0_TDI_Comfortline
# 14  2016-03-21 12:57:01  Nissan_Navara_2.5DPF_SE4x4_Klima_Sitzheizg_Blu...
#
#     seller offerType  price   abtest  vehicleType  yearOfRegistration  \
# 1   privat   Angebot  18300     test            7                2011
# 4   privat   Angebot   3600     test            2                2008
# 8   privat   Angebot  14500  control            4                2014
# 11  privat   Angebot   2799  control            3                2005
# 14  privat   Angebot  17999  control            6                2011
#
#     gearbox  powerPS   model  kilometer  monthOfRegistration fuelType  \
# ...

# %%
second_cars['vehicleType'] = second_cars['vehicleType'].fillna('missing') #filling missing values
second_cars['vehicleType'] = second_cars['vehicleType'].map({
                                                'missing':0,
                                                'limousine':1, 
                                                'kleinwagen':2,
                                                'kombi':3,
                                                'bus':4,
                                                'cabrio':5,
                                                'suv':6,
                                                'coupe':7,
                                                'andere':8})

# %%
second_cars.head()
# Out:
#             dateCrawled                                               name  \
# 1   2016-03-24 10:58:45                               A5_Sportback_2.7_Tdi
# 4   2016-03-31 17:25:20                     Skoda_Fabia_1.4_TDI_PD_Classic
# 8   2016-04-04 23:42:13               Ford_C___Max_Titanium_1_0_L_EcoBoost
# 11  2016-04-07 10:06:22      Volkswagen_Passat_Variant_2.0_TDI_Comfortline
# 14  2016-03-21 12:57:01  Nissan_Navara_2.5DPF_SE4x4_Klima_Sitzheizg_Blu...
#
#     seller offerType  price   abtest  vehicleType  yearOfRegistration  \
# 1   privat   Angebot  18300     test            7                2011
# 4   privat   Angebot   3600     test            2                2008
# 8   privat   Angebot  14500  control            4                2014
# 11  privat   Angebot   2799  control            3                2005
# 14  privat   Angebot  17999  control            6                2011
#
#     gearbox  powerPS   model  kilometer  monthOfRegistration fuelType  \
# ...

# %%
second_cars['vehicleType'] = second_cars['vehicleType'].fillna('missing') #filling missing values
second_cars['vehicleType'] = second_cars['vehicleType'].map({
                                                'missing':0,
                                                'limousine':1, 
                                                'kleinwagen':2,
                                                'kombi':3,
                                                'bus':4,
                                                'cabrio':5,
                                                'suv':6,
                                                'coupe':7,
                                                'andere':8})

# %%
second_cars.tail()
# Out:
#                 dateCrawled  \
# 371517  2016-03-28 13:48:07
# 371518  2016-04-02 20:37:03
# 371519  2016-03-09 13:37:43
# 371523  2016-03-14 17:48:27
# 371527  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 371517                   Volkswagen_Golf_2.0_TDI_DPF_Team  privat   Angebot
# 371518                          Bmw_320_D_DPF_Touring_!!!  privat   Angebot
# 371519  Alfa_Romeo_159_Jtdm_1.9_150_ps_13_600_km_top_voll  privat   Angebot
# 371523                         Suche_t4___vito_ab_6_sitze  privat   Angebot
# 371527       BMW_M135i_vollausgestattet_NP_52.720____Euro  privat   Angebot
#
#         price   abtest  vehicleType  yearOfRegistration    gearbox  powerPS  \
# 371517   7900     test            0                2010    manuell      140
# 371518   3999     test            0                2005    manuell        3
# 371519   5250  control            0                2016  automatik      150
# ...

# %%
second_cars['gearbox'] = second_cars['gearbox'].fillna('missing')
second_cars['gearbox'] = second_cars['gearbox'].map({
                                        'manuell':0,
                                        'automatik':1,
                                        'missing':2})

# %%
second_cars.tail()
# Out:
#                 dateCrawled  \
# 371517  2016-03-28 13:48:07
# 371518  2016-04-02 20:37:03
# 371519  2016-03-09 13:37:43
# 371523  2016-03-14 17:48:27
# 371527  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 371517                   Volkswagen_Golf_2.0_TDI_DPF_Team  privat   Angebot
# 371518                          Bmw_320_D_DPF_Touring_!!!  privat   Angebot
# 371519  Alfa_Romeo_159_Jtdm_1.9_150_ps_13_600_km_top_voll  privat   Angebot
# 371523                         Suche_t4___vito_ab_6_sitze  privat   Angebot
# 371527       BMW_M135i_vollausgestattet_NP_52.720____Euro  privat   Angebot
#
#         price   abtest  vehicleType  yearOfRegistration  gearbox  powerPS  \
# 371517   7900     test            0                2010        0      140
# 371518   3999     test            0                2005        0        3
# 371519   5250  control            0                2016        1      150
# ...

# %%
second_cars = second_cars [second_cars.powerPS > 40]

# %%
second_cars.head()
# Out:
#             dateCrawled                                               name  \
# 1   2016-03-24 10:58:45                               A5_Sportback_2.7_Tdi
# 4   2016-03-31 17:25:20                     Skoda_Fabia_1.4_TDI_PD_Classic
# 8   2016-04-04 23:42:13               Ford_C___Max_Titanium_1_0_L_EcoBoost
# 11  2016-04-07 10:06:22      Volkswagen_Passat_Variant_2.0_TDI_Comfortline
# 14  2016-03-21 12:57:01  Nissan_Navara_2.5DPF_SE4x4_Klima_Sitzheizg_Blu...
#
#     seller offerType  price   abtest  vehicleType  yearOfRegistration  \
# 1   privat   Angebot  18300     test            0                2011
# 4   privat   Angebot   3600     test            0                2008
# 8   privat   Angebot  14500  control            0                2014
# 11  privat   Angebot   2799  control            0                2005
# 14  privat   Angebot  17999  control            0                2011
#
#     gearbox  powerPS   model  kilometer  monthOfRegistration fuelType  \
# ...

# %%
second_cars.isnull(vehicleType)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-52335a8a09df> in <module>()
# ----> 1 second_cars.isnull(vehicleType)
#
# NameError: name 'vehicleType' is not defined

# %%
head(second_cars$notRepairedDamage)
# Out:
#   File "<ipython-input-35-a2e7dbd97ca8>", line 1
#     head(second_cars$notRepairedDamage)
#                     ^
# SyntaxError: invalid syntax

# %%
head(second_cars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-6d96964a4960> in <module>()
# ----> 1 head(second_cars)
#
# NameError: name 'head' is not defined

# %%
second_cars['fuelType'] = second_cars['fuelType'].fillna('missing') #filling missing values
second_cars['fuelType'] = second_cars['fuelType'].map({
                                                'missing':0,
                                                'benzin':1, 
                                                'diesel':2,
                                                'lpg':3,
                                                'cng':4,
                                                'hybrid':5,
                                                'elektro':6,
                                                'andere':7})
